# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt

seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

df_pre = pd.read_csv('../Downloads/deeplearning/dataset/wine.csv', header = None)
df = df_pre.sample(frac = 1)

dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:, 12]

model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

MODEL_DIR = './model'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = "./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only = True)

model.fit(X, Y, validation_split = 0.2, epochs = 200, batch_size = 200, verbose = 0, callbacks = [checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 1.78705, saving model to ./model/01-1.7870.hdf5
#
# Epoch 00002: val_loss improved from 1.78705 to 0.30341, saving model to ./model/02-0.3034.hdf5
#
# Epoch 00003: val_loss improved from 0.30341 to 0.23672, saving model to ./model/03-0.2367.hdf5
#
# Epoch 00004: val_loss improved from 0.23672 to 0.21826, saving model to ./model/04-0.2183.hdf5
#
# Epoch 00005: val_loss improved from 0.21826 to 0.20800, saving model to ./model/05-0.2080.hdf5
#
# Epoch 00006: val_loss improved from 0.20800 to 0.20370, saving model to ./model/06-0.2037.hdf5
#
# Epoch 00007: val_loss improved from 0.20370 to 0.19884, saving model to ./model/07-0.1988.hdf5
#
# Epoch 00008: val_loss improved from 0.19884 to 0.19788, saving model to ./model/08-0.1979.hdf5
#
# Epoch 00009: val_loss improved from 0.19788 to 0.19301, saving model to ./model/09-0.1930.hdf5
#
# Epoch 00010: val_loss did not improve from 0.19301
#
# Epoch 00011: val_loss improved from 0.19301 to 0.18999, saving model to ./model/11-0.1900.hdf5
#
# Epoch 00012: val_loss improved from 0.18999 to 0.18926, saving model to ./model/12-0.1893.hdf5
#
# Epoch 00013: val_loss improved from 0.18926 to 0.18685, saving model to ./model/13-0.1869.hdf5
#
# Epoch 00014: val_loss improved from 0.18685 to 0.18593, saving model to ./model/14-0.1859.hdf5
#
# Epoch 00015: val_loss did not improve from 0.18593
#
# Epoch 00016: val_loss did not improve from 0.18593
#
# Epoch 00017: val_loss improved from 0.18593 to 0.17980, saving model to ./model/17-0.1798.hdf5
#
# Epoch 00018: val_loss improved from 0.17980 to 0.17966, saving model to ./model/18-0.1797.hdf5
#
# Epoch 00019: val_loss improved from 0.17966 to 0.17615, saving model to ./model/19-0.1761.hdf5
#
# Epoch 00020: val_loss improved from 0.17615 to 0.17426, saving model to ./model/20-0.1743.hdf5
#
# Epoch 00021: val_loss improved from 0.17426 to 0.17180, saving model to ./model/21-0.1718.hdf5
#
# Epoch 00022: val_loss improved from 0.17180 to 0.17125, saving model to ./model/22-0.1713.hdf5
#
# Epoch 00023: val_loss improved from 0.17125 to 0.16847, saving model to ./model/23-0.1685.hdf5
#
# Epoch 00024: val_loss did not improve from 0.16847
#
# Epoch 00025: val_loss improved from 0.16847 to 0.16477, saving model to ./model/25-0.1648.hdf5
#
# Epoch 00026: val_loss improved from 0.16477 to 0.16246, saving model to ./model/26-0.1625.hdf5
#
# Epoch 00027: val_loss improved from 0.16246 to 0.15875, saving model to ./model/27-0.1587.hdf5
#
# Epoch 00028: val_loss improved from 0.15875 to 0.15558, saving model to ./model/28-0.1556.hdf5
#
# Epoch 00029: val_loss improved from 0.15558 to 0.15258, saving model to ./model/29-0.1526.hdf5
#
# Epoch 00030: val_loss improved from 0.15258 to 0.15021, saving model to ./model/30-0.1502.hdf5
#
# Epoch 00031: val_loss improved from 0.15021 to 0.14804, saving model to ./model/31-0.1480.hdf5
#
# Epoch 00032: val_loss did not improve from 0.14804
#
# Epoch 00033: val_loss improved from 0.14804 to 0.14175, saving model to ./model/33-0.1417.hdf5
#
# Epoch 00034: val_loss improved from 0.14175 to 0.13858, saving model to ./model/34-0.1386.hdf5
#
# Epoch 00035: val_loss improved from 0.13858 to 0.13838, saving model to ./model/35-0.1384.hdf5
#
# Epoch 00036: val_loss improved from 0.13838 to 0.13326, saving model to ./model/36-0.1333.hdf5
#
# Epoch 00037: val_loss did not improve from 0.13326
#
# Epoch 00038: val_loss improved from 0.13326 to 0.12795, saving model to ./model/38-0.1280.hdf5
#
# Epoch 00039: val_loss improved from 0.12795 to 0.12592, saving model to ./model/39-0.1259.hdf5
#
# Epoch 00040: val_loss improved from 0.12592 to 0.12547, saving model to ./model/40-0.1255.hdf5
#
# Epoch 00041: val_loss improved from 0.12547 to 0.12005, saving model to ./model/41-0.1201.hdf5
#
# Epoch 00042: val_loss did not improve from 0.12005
#
# Epoch 00043: val_loss improved from 0.12005 to 0.11885, saving model to ./model/43-0.1188.hdf5
#
# Epoch 00044: val_loss improved from 0.11885 to 0.11341, saving model to ./model/44-0.1134.hdf5
#
# Epoch 00045: val_loss improved from 0.11341 to 0.11155, saving model to ./model/45-0.1116.hdf5
#
# Epoch 00046: val_loss did not improve from 0.11155
#
# Epoch 00047: val_loss improved from 0.11155 to 0.10757, saving model to ./model/47-0.1076.hdf5
#
# Epoch 00048: val_loss did not improve from 0.10757
#
# Epoch 00049: val_loss improved from 0.10757 to 0.10450, saving model to ./model/49-0.1045.hdf5
#
# Epoch 00050: val_loss improved from 0.10450 to 0.10270, saving model to ./model/50-0.1027.hdf5
#
# Epoch 00051: val_loss improved from 0.10270 to 0.09867, saving model to ./model/51-0.0987.hdf5
#
# Epoch 00052: val_loss did not improve from 0.09867
#
# Epoch 00053: val_loss did not improve from 0.09867
#
# Epoch 00054: val_loss improved from 0.09867 to 0.09567, saving model to ./model/54-0.0957.hdf5
#
# Epoch 00055: val_loss improved from 0.09567 to 0.09382, saving model to ./model/55-0.0938.hdf5
#
# Epoch 00056: val_loss did not improve from 0.09382
#
# Epoch 00057: val_loss did not improve from 0.09382
#
# Epoch 00058: val_loss improved from 0.09382 to 0.08896, saving model to ./model/58-0.0890.hdf5
#
# Epoch 00059: val_loss improved from 0.08896 to 0.08708, saving model to ./model/59-0.0871.hdf5
#
# Epoch 00060: val_loss improved from 0.08708 to 0.08616, saving model to ./model/60-0.0862.hdf5
#
# Epoch 00061: val_loss did not improve from 0.08616
#
# Epoch 00062: val_loss did not improve from 0.08616
#
# Epoch 00063: val_loss improved from 0.08616 to 0.08280, saving model to ./model/63-0.0828.hdf5
#
# Epoch 00064: val_loss improved from 0.08280 to 0.07982, saving model to ./model/64-0.0798.hdf5
#
# Epoch 00065: val_loss did not improve from 0.07982
#
# Epoch 00066: val_loss improved from 0.07982 to 0.07763, saving model to ./model/66-0.0776.hdf5
#
# Epoch 00067: val_loss did not improve from 0.07763
#
# Epoch 00068: val_loss did not improve from 0.07763
#
# Epoch 00069: val_loss improved from 0.07763 to 0.07727, saving model to ./model/69-0.0773.hdf5
#
# Epoch 00070: val_loss improved from 0.07727 to 0.07321, saving model to ./model/70-0.0732.hdf5
#
# Epoch 00071: val_loss did not improve from 0.07321
#
# Epoch 00072: val_loss improved from 0.07321 to 0.07237, saving model to ./model/72-0.0724.hdf5
#
# Epoch 00073: val_loss improved from 0.07237 to 0.07054, saving model to ./model/73-0.0705.hdf5
#
# Epoch 00074: val_loss did not improve from 0.07054
#
# Epoch 00075: val_loss improved from 0.07054 to 0.06944, saving model to ./model/75-0.0694.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06944
#
# Epoch 00077: val_loss did not improve from 0.06944
#
# Epoch 00078: val_loss did not improve from 0.06944
#
# Epoch 00079: val_loss did not improve from 0.06944
#
# Epoch 00080: val_loss improved from 0.06944 to 0.06579, saving model to ./model/80-0.0658.hdf5
#
# Epoch 00081: val_loss did not improve from 0.06579
#
# Epoch 00082: val_loss did not improve from 0.06579
#
# Epoch 00083: val_loss improved from 0.06579 to 0.06445, saving model to ./model/83-0.0644.hdf5
#
# Epoch 00084: val_loss did not improve from 0.06445
#
# Epoch 00085: val_loss improved from 0.06445 to 0.06424, saving model to ./model/85-0.0642.hdf5
#
# Epoch 00086: val_loss improved from 0.06424 to 0.06180, saving model to ./model/86-0.0618.hdf5
#
# Epoch 00087: val_loss improved from 0.06180 to 0.06178, saving model to ./model/87-0.0618.hdf5
#
# Epoch 00088: val_loss did not improve from 0.06178
#
# Epoch 00089: val_loss did not improve from 0.06178
#
# Epoch 00090: val_loss did not improve from 0.06178
#
# Epoch 00091: val_loss improved from 0.06178 to 0.06093, saving model to ./model/91-0.0609.hdf5
#
# Epoch 00092: val_loss did not improve from 0.06093
#
# Epoch 00093: val_loss improved from 0.06093 to 0.06074, saving model to ./model/93-0.0607.hdf5
#
# Epoch 00094: val_loss did not improve from 0.06074
#
# Epoch 00095: val_loss improved from 0.06074 to 0.06029, saving model to ./model/95-0.0603.hdf5
#
# Epoch 00096: val_loss improved from 0.06029 to 0.06010, saving model to ./model/96-0.0601.hdf5
#
# Epoch 00097: val_loss improved from 0.06010 to 0.05879, saving model to ./model/97-0.0588.hdf5
#
# Epoch 00098: val_loss did not improve from 0.05879
#
# Epoch 00099: val_loss did not improve from 0.05879
#
# Epoch 00100: val_loss did not improve from 0.05879
#
# Epoch 00101: val_loss improved from 0.05879 to 0.05791, saving model to ./model/101-0.0579.hdf5
#
# Epoch 00102: val_loss did not improve from 0.05791
#
# Epoch 00103: val_loss improved from 0.05791 to 0.05764, saving model to ./model/103-0.0576.hdf5
#
# Epoch 00104: val_loss did not improve from 0.05764
#
# Epoch 00105: val_loss improved from 0.05764 to 0.05685, saving model to ./model/105-0.0568.hdf5
# Epoch 00106: val_loss did not improve from 0.05685
#
# Epoch 00107: val_loss did not improve from 0.05685
#
# Epoch 00108: val_loss did not improve from 0.05685
#
# Epoch 00109: val_loss did not improve from 0.05685
#
# Epoch 00110: val_loss did not improve from 0.05685
#
# Epoch 00111: val_loss improved from 0.05685 to 0.05656, saving model to ./model/111-0.0566.hdf5
#
# Epoch 00112: val_loss did not improve from 0.05656
#
# Epoch 00113: val_loss did not improve from 0.05656
#
# Epoch 00114: val_loss improved from 0.05656 to 0.05619, saving model to ./model/114-0.0562.hdf5
#
# Epoch 00115: val_loss did not improve from 0.05619
#
# Epoch 00116: val_loss did not improve from 0.05619
#
# Epoch 00117: val_loss did not improve from 0.05619
#
# Epoch 00118: val_loss improved from 0.05619 to 0.05521, saving model to ./model/118-0.0552.hdf5
#
# Epoch 00119: val_loss did not improve from 0.05521
#
# Epoch 00120: val_loss improved from 0.05521 to 0.05497, saving model to ./model/120-0.0550.hdf5
#
# Epoch 00121: val_loss did not improve from 0.05497
#
# Epoch 00122: val_loss did not improve from 0.05497
#
# Epoch 00123: val_loss improved from 0.05497 to 0.05487, saving model to ./model/123-0.0549.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05487
#
# Epoch 00125: val_loss improved from 0.05487 to 0.05450, saving model to ./model/125-0.0545.hdf5
#
# Epoch 00126: val_loss did not improve from 0.05450
#
# Epoch 00127: val_loss did not improve from 0.05450
#
# Epoch 00128: val_loss did not improve from 0.05450
#
# Epoch 00129: val_loss did not improve from 0.05450
#
# Epoch 00130: val_loss improved from 0.05450 to 0.05373, saving model to ./model/130-0.0537.hdf5
#
# Epoch 00131: val_loss did not improve from 0.05373
#
# Epoch 00132: val_loss did not improve from 0.05373
#
# Epoch 00133: val_loss did not improve from 0.05373
#
# Epoch 00134: val_loss did not improve from 0.05373
#
# Epoch 00135: val_loss did not improve from 0.05373
#
# Epoch 00136: val_loss did not improve from 0.05373
#
# Epoch 00137: val_loss did not improve from 0.05373
#
# Epoch 00138: val_loss did not improve from 0.05373
#
# Epoch 00139: val_loss improved from 0.05373 to 0.05352, saving model to ./model/139-0.0535.hdf5
#
# Epoch 00140: val_loss did not improve from 0.05352
#
# Epoch 00141: val_loss did not improve from 0.05352
#
# Epoch 00142: val_loss did not improve from 0.05352
#
# Epoch 00143: val_loss improved from 0.05352 to 0.05297, saving model to ./model/143-0.0530.hdf5
#
# Epoch 00144: val_loss did not improve from 0.05297
#
# Epoch 00145: val_loss did not improve from 0.05297
#
# Epoch 00146: val_loss did not improve from 0.05297
#
# Epoch 00147: val_loss did not improve from 0.05297
#
# Epoch 00148: val_loss did not improve from 0.05297
#
# Epoch 00149: val_loss did not improve from 0.05297
#
# Epoch 00150: val_loss improved from 0.05297 to 0.05242, saving model to ./model/150-0.0524.hdf5
#
# Epoch 00151: val_loss did not improve from 0.05242
#
# Epoch 00152: val_loss did not improve from 0.05242
#
# Epoch 00153: val_loss did not improve from 0.05242
#
# Epoch 00154: val_loss did not improve from 0.05242
#
# Epoch 00155: val_loss did not improve from 0.05242
#
# Epoch 00156: val_loss did not improve from 0.05242
#
# Epoch 00157: val_loss did not improve from 0.05242
#
# Epoch 00158: val_loss improved from 0.05242 to 0.05180, saving model to ./model/158-0.0518.hdf5
#
# Epoch 00159: val_loss did not improve from 0.05180
#
# Epoch 00160: val_loss did not improve from 0.05180
#
# Epoch 00161: val_loss did not improve from 0.05180
#
# Epoch 00162: val_loss did not improve from 0.05180
#
# Epoch 00163: val_loss did not improve from 0.05180
#
# Epoch 00164: val_loss did not improve from 0.05180
#
# Epoch 00165: val_loss did not improve from 0.05180
#
# Epoch 00166: val_loss did not improve from 0.05180
#
# Epoch 00167: val_loss did not improve from 0.05180
#
# Epoch 00168: val_loss did not improve from 0.05180
#
# Epoch 00169: val_loss did not improve from 0.05180
#
# Epoch 00170: val_loss did not improve from 0.05180
#
# Epoch 00171: val_loss did not improve from 0.05180
#
# Epoch 00172: val_loss did not improve from 0.05180
#
# Epoch 00173: val_loss did not improve from 0.05180
#
# Epoch 00174: val_loss did not improve from 0.05180
#
# Epoch 00175: val_loss did not improve from 0.05180
#
# Epoch 00176: val_loss did not improve from 0.05180
#
# Epoch 00177: val_loss did not improve from 0.05180
#
# Epoch 00178: val_loss did not improve from 0.05180
#
# Epoch 00179: val_loss did not improve from 0.05180
#
# Epoch 00180: val_loss did not improve from 0.05180
#
# Epoch 00181: val_loss improved from 0.05180 to 0.05158, saving model to ./model/181-0.0516.hdf5
#
# Epoch 00182: val_loss did not improve from 0.05158
#
# Epoch 00183: val_loss improved from 0.05158 to 0.05152, saving model to ./model/183-0.0515.hdf5
#
# Epoch 00184: val_loss did not improve from 0.05152
#
# Epoch 00185: val_loss did not improve from 0.05152
#
# Epoch 00186: val_loss did not improve from 0.05152
#
# Epoch 00187: val_loss improved from 0.05152 to 0.05143, saving model to ./model/187-0.0514.hdf5
#
# Epoch 00188: val_loss did not improve from 0.05143
#
# Epoch 00189: val_loss did not improve from 0.05143
#
# Epoch 00190: val_loss improved from 0.05143 to 0.05100, saving model to ./model/190-0.0510.hdf5
#
# Epoch 00191: val_loss did not improve from 0.05100
#
# Epoch 00192: val_loss did not improve from 0.05100
#
# Epoch 00193: val_loss improved from 0.05100 to 0.05089, saving model to ./model/193-0.0509.hdf5
#
# Epoch 00194: val_loss did not improve from 0.05089
#
# Epoch 00195: val_loss did not improve from 0.05089
#
# Epoch 00196: val_loss did not improve from 0.05089
#
# Epoch 00197: val_loss did not improve from 0.05089
#
# Epoch 00198: val_loss did not improve from 0.05089
#
# Epoch 00199: val_loss did not improve from 0.05089
#
# Epoch 00200: val_loss did not improve from 0.05089
