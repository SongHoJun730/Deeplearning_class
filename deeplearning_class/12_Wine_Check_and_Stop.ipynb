# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt

seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

df_pre = pd.read_csv('../Downloads/deeplearning/dataset/wine.csv', header = None)
df = df_pre.sample(frac = 0.15)

dataset = df.values
X = dataset[:, 0:12]
Y = dataset[:, 12]

model = Sequential()
model.add(Dense(30, input_dim = 12 , activation = 'relu'))
model.add(Dense(12 , activation = 'relu'))
model.add(Dense(8 , activation = 'relu'))
model.add(Dense(1 , activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath = "./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 1, save_best_only = True)

early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 100)

model.fit(X, Y,validation_split = 0.2, epochs = 3500, batch_size = 500, verbose = 0, callbacks = [early_stopping_callback, checkpointer])

print("\n Accuracy : %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 00001: val_loss improved from inf to 7.49616, saving model to ./model/01-7.4962.hdf5
#
# Epoch 00002: val_loss improved from 7.49616 to 6.54614, saving model to ./model/02-6.5461.hdf5
#
# Epoch 00003: val_loss improved from 6.54614 to 5.78395, saving model to ./model/03-5.7839.hdf5
#
# Epoch 00004: val_loss improved from 5.78395 to 5.07433, saving model to ./model/04-5.0743.hdf5
#
# Epoch 00005: val_loss improved from 5.07433 to 4.37800, saving model to ./model/05-4.3780.hdf5
#
# Epoch 00006: val_loss improved from 4.37800 to 3.70057, saving model to ./model/06-3.7006.hdf5
#
# Epoch 00007: val_loss improved from 3.70057 to 3.13307, saving model to ./model/07-3.1331.hdf5
#
# Epoch 00008: val_loss improved from 3.13307 to 2.76107, saving model to ./model/08-2.7611.hdf5
#
# Epoch 00009: val_loss improved from 2.76107 to 2.52008, saving model to ./model/09-2.5201.hdf5
#
# Epoch 00010: val_loss improved from 2.52008 to 2.33329, saving model to ./model/10-2.3333.hdf5
#
# Epoch 00011: val_loss improved from 2.33329 to 2.15495, saving model to ./model/11-2.1550.hdf5
#
# Epoch 00012: val_loss improved from 2.15495 to 1.97594, saving model to ./model/12-1.9759.hdf5
#
# Epoch 00013: val_loss improved from 1.97594 to 1.78777, saving model to ./model/13-1.7878.hdf5
#
# Epoch 00014: val_loss improved from 1.78777 to 1.58808, saving model to ./model/14-1.5881.hdf5
#
# Epoch 00015: val_loss improved from 1.58808 to 1.38351, saving model to ./model/15-1.3835.hdf5
#
# Epoch 00016: val_loss improved from 1.38351 to 1.18027, saving model to ./model/16-1.1803.hdf5
#
# Epoch 00017: val_loss improved from 1.18027 to 0.98732, saving model to ./model/17-0.9873.hdf5
#
# Epoch 00018: val_loss improved from 0.98732 to 0.81795, saving model to ./model/18-0.8179.hdf5
#
# Epoch 00019: val_loss improved from 0.81795 to 0.67620, saving model to ./model/19-0.6762.hdf5
#
# Epoch 00020: val_loss improved from 0.67620 to 0.56488, saving model to ./model/20-0.5649.hdf5
#
# Epoch 00021: val_loss improved from 0.56488 to 0.48266, saving model to ./model/21-0.4827.hdf5
#
# Epoch 00022: val_loss improved from 0.48266 to 0.42267, saving model to ./model/22-0.4227.hdf5
#
# Epoch 00023: val_loss improved from 0.42267 to 0.38030, saving model to ./model/23-0.3803.hdf5
#
# Epoch 00024: val_loss improved from 0.38030 to 0.35085, saving model to ./model/24-0.3509.hdf5
#
# Epoch 00025: val_loss improved from 0.35085 to 0.33027, saving model to ./model/25-0.3303.hdf5
#
# Epoch 00026: val_loss improved from 0.33027 to 0.31560, saving model to ./model/26-0.3156.hdf5
#
# Epoch 00027: val_loss improved from 0.31560 to 0.30458, saving model to ./model/27-0.3046.hdf5
#
# Epoch 00028: val_loss improved from 0.30458 to 0.29623, saving model to ./model/28-0.2962.hdf5
#
# Epoch 00029: val_loss improved from 0.29623 to 0.28958, saving model to ./model/29-0.2896.hdf5
#
# Epoch 00030: val_loss improved from 0.28958 to 0.28428, saving model to ./model/30-0.2843.hdf5
#
# Epoch 00031: val_loss improved from 0.28428 to 0.28000, saving model to ./model/31-0.2800.hdf5
#
# Epoch 00032: val_loss improved from 0.28000 to 0.27643, saving model to ./model/32-0.2764.hdf5
#
# Epoch 00033: val_loss improved from 0.27643 to 0.27327, saving model to ./model/33-0.2733.hdf5
#
# Epoch 00034: val_loss improved from 0.27327 to 0.27062, saving model to ./model/34-0.2706.hdf5
#
# Epoch 00035: val_loss improved from 0.27062 to 0.26786, saving model to ./model/35-0.2679.hdf5
#
# Epoch 00036: val_loss improved from 0.26786 to 0.26533, saving model to ./model/36-0.2653.hdf5
#
# Epoch 00037: val_loss improved from 0.26533 to 0.26285, saving model to ./model/37-0.2628.hdf5
#
# Epoch 00038: val_loss improved from 0.26285 to 0.26037, saving model to ./model/38-0.2604.hdf5
#
# Epoch 00039: val_loss improved from 0.26037 to 0.25777, saving model to ./model/39-0.2578.hdf5
#
# Epoch 00040: val_loss improved from 0.25777 to 0.25508, saving model to ./model/40-0.2551.hdf5
#
# Epoch 00041: val_loss improved from 0.25508 to 0.25218, saving model to ./model/41-0.2522.hdf5
#
# Epoch 00042: val_loss improved from 0.25218 to 0.24958, saving model to ./model/42-0.2496.hdf5
#
# Epoch 00043: val_loss improved from 0.24958 to 0.24728, saving model to ./model/43-0.2473.hdf5
#
# Epoch 00044: val_loss improved from 0.24728 to 0.24545, saving model to ./model/44-0.2455.hdf5
#
# Epoch 00045: val_loss improved from 0.24545 to 0.24398, saving model to ./model/45-0.2440.hdf5
#
# Epoch 00046: val_loss improved from 0.24398 to 0.24251, saving model to ./model/46-0.2425.hdf5
#
# Epoch 00047: val_loss improved from 0.24251 to 0.24126, saving model to ./model/47-0.2413.hdf5
#
# Epoch 00048: val_loss improved from 0.24126 to 0.24001, saving model to ./model/48-0.2400.hdf5
#
# Epoch 00049: val_loss improved from 0.24001 to 0.23874, saving model to ./model/49-0.2387.hdf5
#
# Epoch 00050: val_loss improved from 0.23874 to 0.23756, saving model to ./model/50-0.2376.hdf5
#
# Epoch 00051: val_loss improved from 0.23756 to 0.23651, saving model to ./model/51-0.2365.hdf5
#
# Epoch 00052: val_loss improved from 0.23651 to 0.23557, saving model to ./model/52-0.2356.hdf5
#
# Epoch 00053: val_loss improved from 0.23557 to 0.23479, saving model to ./model/53-0.2348.hdf5
#
# Epoch 00054: val_loss improved from 0.23479 to 0.23414, saving model to ./model/54-0.2341.hdf5
#
# Epoch 00055: val_loss improved from 0.23414 to 0.23353, saving model to ./model/55-0.2335.hdf5
#
# Epoch 00056: val_loss improved from 0.23353 to 0.23295, saving model to ./model/56-0.2330.hdf5
#
# Epoch 00057: val_loss improved from 0.23295 to 0.23233, saving model to ./model/57-0.2323.hdf5
#
# Epoch 00058: val_loss improved from 0.23233 to 0.23170, saving model to ./model/58-0.2317.hdf5
#
# Epoch 00059: val_loss improved from 0.23170 to 0.23113, saving model to ./model/59-0.2311.hdf5
#
# Epoch 00060: val_loss improved from 0.23113 to 0.23063, saving model to ./model/60-0.2306.hdf5
#
# Epoch 00061: val_loss improved from 0.23063 to 0.23014, saving model to ./model/61-0.2301.hdf5
#
# Epoch 00062: val_loss improved from 0.23014 to 0.22965, saving model to ./model/62-0.2296.hdf5
#
# Epoch 00063: val_loss improved from 0.22965 to 0.22909, saving model to ./model/63-0.2291.hdf5
#
# Epoch 00064: val_loss improved from 0.22909 to 0.22854, saving model to ./model/64-0.2285.hdf5
#
# Epoch 00065: val_loss improved from 0.22854 to 0.22793, saving model to ./model/65-0.2279.hdf5
#
# Epoch 00066: val_loss improved from 0.22793 to 0.22735, saving model to ./model/66-0.2273.hdf5
#
# Epoch 00067: val_loss improved from 0.22735 to 0.22678, saving model to ./model/67-0.2268.hdf5
#
# Epoch 00068: val_loss improved from 0.22678 to 0.22615, saving model to ./model/68-0.2262.hdf5
#
# Epoch 00069: val_loss improved from 0.22615 to 0.22549, saving model to ./model/69-0.2255.hdf5
#
# Epoch 00070: val_loss improved from 0.22549 to 0.22486, saving model to ./model/70-0.2249.hdf5
#
# Epoch 00071: val_loss improved from 0.22486 to 0.22427, saving model to ./model/71-0.2243.hdf5
#
# Epoch 00072: val_loss improved from 0.22427 to 0.22399, saving model to ./model/72-0.2240.hdf5
#
# Epoch 00073: val_loss improved from 0.22399 to 0.22371, saving model to ./model/73-0.2237.hdf5
#
# Epoch 00074: val_loss improved from 0.22371 to 0.22341, saving model to ./model/74-0.2234.hdf5
#
# Epoch 00075: val_loss improved from 0.22341 to 0.22307, saving model to ./model/75-0.2231.hdf5
#
# Epoch 00076: val_loss improved from 0.22307 to 0.22246, saving model to ./model/76-0.2225.hdf5
#
# Epoch 00077: val_loss improved from 0.22246 to 0.22168, saving model to ./model/77-0.2217.hdf5
#
# Epoch 00078: val_loss improved from 0.22168 to 0.22113, saving model to ./model/78-0.2211.hdf5
#
# Epoch 00079: val_loss improved from 0.22113 to 0.22057, saving model to ./model/79-0.2206.hdf5
#
# Epoch 00080: val_loss improved from 0.22057 to 0.22016, saving model to ./model/80-0.2202.hdf5
#
# Epoch 00081: val_loss improved from 0.22016 to 0.21987, saving model to ./model/81-0.2199.hdf5
#
# Epoch 00082: val_loss improved from 0.21987 to 0.21976, saving model to ./model/82-0.2198.hdf5
#
# Epoch 00083: val_loss improved from 0.21976 to 0.21965, saving model to ./model/83-0.2197.hdf5
#
# Epoch 00084: val_loss improved from 0.21965 to 0.21958, saving model to ./model/84-0.2196.hdf5
#
# Epoch 00085: val_loss improved from 0.21958 to 0.21945, saving model to ./model/85-0.2195.hdf5
#
# Epoch 00086: val_loss improved from 0.21945 to 0.21919, saving model to ./model/86-0.2192.hdf5
#
# Epoch 00087: val_loss improved from 0.21919 to 0.21886, saving model to ./model/87-0.2189.hdf5
#
# Epoch 00088: val_loss improved from 0.21886 to 0.21853, saving model to ./model/88-0.2185.hdf5
#
# Epoch 00089: val_loss improved from 0.21853 to 0.21811, saving model to ./model/89-0.2181.hdf5
#
# Epoch 00090: val_loss improved from 0.21811 to 0.21776, saving model to ./model/90-0.2178.hdf5
# Epoch 00091: val_loss improved from 0.21776 to 0.21747, saving model to ./model/91-0.2175.hdf5
#
# Epoch 00092: val_loss improved from 0.21747 to 0.21716, saving model to ./model/92-0.2172.hdf5
#
# Epoch 00093: val_loss improved from 0.21716 to 0.21690, saving model to ./model/93-0.2169.hdf5
#
# Epoch 00094: val_loss improved from 0.21690 to 0.21675, saving model to ./model/94-0.2168.hdf5
#
# Epoch 00095: val_loss improved from 0.21675 to 0.21662, saving model to ./model/95-0.2166.hdf5
#
# Epoch 00096: val_loss improved from 0.21662 to 0.21650, saving model to ./model/96-0.2165.hdf5
#
# Epoch 00097: val_loss improved from 0.21650 to 0.21648, saving model to ./model/97-0.2165.hdf5
#
# Epoch 00098: val_loss improved from 0.21648 to 0.21619, saving model to ./model/98-0.2162.hdf5
#
# Epoch 00099: val_loss improved from 0.21619 to 0.21570, saving model to ./model/99-0.2157.hdf5
#
# Epoch 00100: val_loss improved from 0.21570 to 0.21523, saving model to ./model/100-0.2152.hdf5
#
# Epoch 00101: val_loss improved from 0.21523 to 0.21432, saving model to ./model/101-0.2143.hdf5
#
# Epoch 00102: val_loss improved from 0.21432 to 0.21265, saving model to ./model/102-0.2126.hdf5
#
# Epoch 00103: val_loss improved from 0.21265 to 0.21013, saving model to ./model/103-0.2101.hdf5
#
# Epoch 00104: val_loss improved from 0.21013 to 0.20802, saving model to ./model/104-0.2080.hdf5
#
# Epoch 00105: val_loss improved from 0.20802 to 0.20579, saving model to ./model/105-0.2058.hdf5
#
# Epoch 00106: val_loss improved from 0.20579 to 0.20345, saving model to ./model/106-0.2034.hdf5
#
# Epoch 00107: val_loss improved from 0.20345 to 0.20117, saving model to ./model/107-0.2012.hdf5
#
# Epoch 00108: val_loss improved from 0.20117 to 0.20054, saving model to ./model/108-0.2005.hdf5
#
# Epoch 00109: val_loss did not improve from 0.20054
#
# Epoch 00110: val_loss did not improve from 0.20054
#
# Epoch 00111: val_loss did not improve from 0.20054
#
# Epoch 00112: val_loss did not improve from 0.20054
#
# Epoch 00113: val_loss did not improve from 0.20054
#
# Epoch 00114: val_loss improved from 0.20054 to 0.20023, saving model to ./model/114-0.2002.hdf5
#
# Epoch 00115: val_loss improved from 0.20023 to 0.19996, saving model to ./model/115-0.2000.hdf5
#
# Epoch 00116: val_loss improved from 0.19996 to 0.19994, saving model to ./model/116-0.1999.hdf5
#
# Epoch 00117: val_loss did not improve from 0.19994
#
# Epoch 00118: val_loss did not improve from 0.19994
#
# Epoch 00119: val_loss did not improve from 0.19994
#
# Epoch 00120: val_loss did not improve from 0.19994
#
# Epoch 00121: val_loss did not improve from 0.19994
#
# Epoch 00122: val_loss improved from 0.19994 to 0.19874, saving model to ./model/122-0.1987.hdf5
#
# Epoch 00123: val_loss improved from 0.19874 to 0.19811, saving model to ./model/123-0.1981.hdf5
#
# Epoch 00124: val_loss improved from 0.19811 to 0.19805, saving model to ./model/124-0.1980.hdf5
#
# Epoch 00125: val_loss did not improve from 0.19805
#
# Epoch 00126: val_loss did not improve from 0.19805
#
# Epoch 00127: val_loss did not improve from 0.19805
#
# Epoch 00128: val_loss did not improve from 0.19805
#
# Epoch 00129: val_loss did not improve from 0.19805
#
# Epoch 00130: val_loss improved from 0.19805 to 0.19742, saving model to ./model/130-0.1974.hdf5
#
# Epoch 00131: val_loss improved from 0.19742 to 0.19704, saving model to ./model/131-0.1970.hdf5
#
# Epoch 00132: val_loss improved from 0.19704 to 0.19659, saving model to ./model/132-0.1966.hdf5
#
# Epoch 00133: val_loss improved from 0.19659 to 0.19647, saving model to ./model/133-0.1965.hdf5
#
# Epoch 00134: val_loss did not improve from 0.19647
#
# Epoch 00135: val_loss improved from 0.19647 to 0.19642, saving model to ./model/135-0.1964.hdf5
#
# Epoch 00136: val_loss improved from 0.19642 to 0.19583, saving model to ./model/136-0.1958.hdf5
#
# Epoch 00137: val_loss improved from 0.19583 to 0.19565, saving model to ./model/137-0.1957.hdf5
#
# Epoch 00138: val_loss did not improve from 0.19565
#
# Epoch 00139: val_loss did not improve from 0.19565
#
# Epoch 00140: val_loss improved from 0.19565 to 0.19512, saving model to ./model/140-0.1951.hdf5
#
# Epoch 00141: val_loss improved from 0.19512 to 0.19419, saving model to ./model/141-0.1942.hdf5
#
# Epoch 00142: val_loss improved from 0.19419 to 0.19368, saving model to ./model/142-0.1937.hdf5
#
# Epoch 00143: val_loss did not improve from 0.19368
#
# Epoch 00144: val_loss did not improve from 0.19368
#
# Epoch 00145: val_loss did not improve from 0.19368
#
# Epoch 00146: val_loss did not improve from 0.19368
#
# Epoch 00147: val_loss did not improve from 0.19368
#
# Epoch 00148: val_loss improved from 0.19368 to 0.19272, saving model to ./model/148-0.1927.hdf5
#
# Epoch 00149: val_loss improved from 0.19272 to 0.19195, saving model to ./model/149-0.1919.hdf5
#
# Epoch 00150: val_loss improved from 0.19195 to 0.19169, saving model to ./model/150-0.1917.hdf5
#
# Epoch 00151: val_loss did not improve from 0.19169
#
# Epoch 00152: val_loss did not improve from 0.19169
#
# Epoch 00153: val_loss did not improve from 0.19169
#
# Epoch 00154: val_loss did not improve from 0.19169
#
# Epoch 00155: val_loss did not improve from 0.19169
#
# Epoch 00156: val_loss improved from 0.19169 to 0.19063, saving model to ./model/156-0.1906.hdf5
#
# Epoch 00157: val_loss improved from 0.19063 to 0.18987, saving model to ./model/157-0.1899.hdf5
#
# Epoch 00158: val_loss improved from 0.18987 to 0.18974, saving model to ./model/158-0.1897.hdf5
#
# Epoch 00159: val_loss did not improve from 0.18974
#
# Epoch 00160: val_loss did not improve from 0.18974
#
# Epoch 00161: val_loss did not improve from 0.18974
#
# Epoch 00162: val_loss did not improve from 0.18974
#
# Epoch 00163: val_loss did not improve from 0.18974
#
# Epoch 00164: val_loss improved from 0.18974 to 0.18837, saving model to ./model/164-0.1884.hdf5
#
# Epoch 00165: val_loss improved from 0.18837 to 0.18797, saving model to ./model/165-0.1880.hdf5
#
# Epoch 00166: val_loss did not improve from 0.18797
#
# Epoch 00167: val_loss did not improve from 0.18797
#
# Epoch 00168: val_loss did not improve from 0.18797
#
# Epoch 00169: val_loss did not improve from 0.18797
#
# Epoch 00170: val_loss did not improve from 0.18797
#
# Epoch 00171: val_loss did not improve from 0.18797
#
# Epoch 00172: val_loss improved from 0.18797 to 0.18696, saving model to ./model/172-0.1870.hdf5
#
# Epoch 00173: val_loss improved from 0.18696 to 0.18682, saving model to ./model/173-0.1868.hdf5
#
# Epoch 00174: val_loss did not improve from 0.18682
#
# Epoch 00175: val_loss did not improve from 0.18682
#
# Epoch 00176: val_loss did not improve from 0.18682
#
# Epoch 00177: val_loss did not improve from 0.18682
#
# Epoch 00178: val_loss improved from 0.18682 to 0.18585, saving model to ./model/178-0.1858.hdf5
#
# Epoch 00179: val_loss improved from 0.18585 to 0.18580, saving model to ./model/179-0.1858.hdf5
#
# Epoch 00180: val_loss did not improve from 0.18580
#
# Epoch 00181: val_loss improved from 0.18580 to 0.18556, saving model to ./model/181-0.1856.hdf5
#
# Epoch 00182: val_loss improved from 0.18556 to 0.18506, saving model to ./model/182-0.1851.hdf5
#
# Epoch 00183: val_loss did not improve from 0.18506
#
# Epoch 00184: val_loss did not improve from 0.18506
#
# Epoch 00185: val_loss did not improve from 0.18506
#
# Epoch 00186: val_loss did not improve from 0.18506
#
# Epoch 00187: val_loss did not improve from 0.18506
#
# Epoch 00188: val_loss did not improve from 0.18506
#
# Epoch 00189: val_loss improved from 0.18506 to 0.18476, saving model to ./model/189-0.1848.hdf5
#
# Epoch 00190: val_loss improved from 0.18476 to 0.18388, saving model to ./model/190-0.1839.hdf5
#
# Epoch 00191: val_loss improved from 0.18388 to 0.18365, saving model to ./model/191-0.1836.hdf5
#
# Epoch 00192: val_loss improved from 0.18365 to 0.18309, saving model to ./model/192-0.1831.hdf5
#
# Epoch 00193: val_loss improved from 0.18309 to 0.18225, saving model to ./model/193-0.1822.hdf5
#
# Epoch 00194: val_loss improved from 0.18225 to 0.18169, saving model to ./model/194-0.1817.hdf5
#
# Epoch 00195: val_loss did not improve from 0.18169
#
# Epoch 00196: val_loss did not improve from 0.18169
#
# Epoch 00197: val_loss did not improve from 0.18169
#
# Epoch 00198: val_loss did not improve from 0.18169
#
# Epoch 00199: val_loss did not improve from 0.18169
#
# Epoch 00200: val_loss did not improve from 0.18169
#
# Epoch 00201: val_loss did not improve from 0.18169
#
# Epoch 00202: val_loss did not improve from 0.18169
#
# Epoch 00203: val_loss did not improve from 0.18169
#
# Epoch 00204: val_loss did not improve from 0.18169
#
# Epoch 00205: val_loss did not improve from 0.18169
#
# Epoch 00206: val_loss did not improve from 0.18169
#
# Epoch 00207: val_loss did not improve from 0.18169
#
# Epoch 00208: val_loss did not improve from 0.18169
#
# Epoch 00209: val_loss did not improve from 0.18169
#
# Epoch 00210: val_loss did not improve from 0.18169
#
# Epoch 00211: val_loss did not improve from 0.18169
#
# Epoch 00212: val_loss did not improve from 0.18169
#
# Epoch 00213: val_loss improved from 0.18169 to 0.18120, saving model to ./model/213-0.1812.hdf5
#
# Epoch 00214: val_loss improved from 0.18120 to 0.18029, saving model to ./model/214-0.1803.hdf5
#
# Epoch 00215: val_loss improved from 0.18029 to 0.17977, saving model to ./model/215-0.1798.hdf5
# Epoch 00216: val_loss improved from 0.17977 to 0.17936, saving model to ./model/216-0.1794.hdf5
#
# Epoch 00217: val_loss improved from 0.17936 to 0.17926, saving model to ./model/217-0.1793.hdf5
#
# Epoch 00218: val_loss did not improve from 0.17926
#
# Epoch 00219: val_loss did not improve from 0.17926
#
# Epoch 00220: val_loss did not improve from 0.17926
#
# Epoch 00221: val_loss did not improve from 0.17926
#
# Epoch 00222: val_loss improved from 0.17926 to 0.17920, saving model to ./model/222-0.1792.hdf5
#
# Epoch 00223: val_loss improved from 0.17920 to 0.17838, saving model to ./model/223-0.1784.hdf5
#
# Epoch 00224: val_loss improved from 0.17838 to 0.17788, saving model to ./model/224-0.1779.hdf5
#
# Epoch 00225: val_loss did not improve from 0.17788
#
# Epoch 00226: val_loss did not improve from 0.17788
#
# Epoch 00227: val_loss did not improve from 0.17788
#
# Epoch 00228: val_loss improved from 0.17788 to 0.17769, saving model to ./model/228-0.1777.hdf5
#
# Epoch 00229: val_loss improved from 0.17769 to 0.17736, saving model to ./model/229-0.1774.hdf5
#
# Epoch 00230: val_loss improved from 0.17736 to 0.17623, saving model to ./model/230-0.1762.hdf5
#
# Epoch 00231: val_loss improved from 0.17623 to 0.17549, saving model to ./model/231-0.1755.hdf5
#
# Epoch 00232: val_loss improved from 0.17549 to 0.17514, saving model to ./model/232-0.1751.hdf5
#
# Epoch 00233: val_loss did not improve from 0.17514
#
# Epoch 00234: val_loss did not improve from 0.17514
#
# Epoch 00235: val_loss did not improve from 0.17514
#
# Epoch 00236: val_loss did not improve from 0.17514
#
# Epoch 00237: val_loss improved from 0.17514 to 0.17479, saving model to ./model/237-0.1748.hdf5
#
# Epoch 00238: val_loss improved from 0.17479 to 0.17402, saving model to ./model/238-0.1740.hdf5
#
# Epoch 00239: val_loss improved from 0.17402 to 0.17355, saving model to ./model/239-0.1736.hdf5
#
# Epoch 00240: val_loss improved from 0.17355 to 0.17288, saving model to ./model/240-0.1729.hdf5
#
# Epoch 00241: val_loss improved from 0.17288 to 0.17264, saving model to ./model/241-0.1726.hdf5
#
# Epoch 00242: val_loss improved from 0.17264 to 0.17187, saving model to ./model/242-0.1719.hdf5
#
# Epoch 00243: val_loss improved from 0.17187 to 0.17161, saving model to ./model/243-0.1716.hdf5
#
# Epoch 00244: val_loss did not improve from 0.17161
#
# Epoch 00245: val_loss did not improve from 0.17161
#
# Epoch 00246: val_loss did not improve from 0.17161
#
# Epoch 00247: val_loss did not improve from 0.17161
#
# Epoch 00248: val_loss did not improve from 0.17161
#
# Epoch 00249: val_loss improved from 0.17161 to 0.17080, saving model to ./model/249-0.1708.hdf5
#
# Epoch 00250: val_loss improved from 0.17080 to 0.16966, saving model to ./model/250-0.1697.hdf5
#
# Epoch 00251: val_loss improved from 0.16966 to 0.16955, saving model to ./model/251-0.1696.hdf5
#
# Epoch 00252: val_loss did not improve from 0.16955
#
# Epoch 00253: val_loss did not improve from 0.16955
#
# Epoch 00254: val_loss did not improve from 0.16955
#
# Epoch 00255: val_loss did not improve from 0.16955
#
# Epoch 00256: val_loss improved from 0.16955 to 0.16893, saving model to ./model/256-0.1689.hdf5
#
# Epoch 00257: val_loss improved from 0.16893 to 0.16857, saving model to ./model/257-0.1686.hdf5
#
# Epoch 00258: val_loss improved from 0.16857 to 0.16845, saving model to ./model/258-0.1685.hdf5
#
# Epoch 00259: val_loss did not improve from 0.16845
#
# Epoch 00260: val_loss did not improve from 0.16845
#
# Epoch 00261: val_loss did not improve from 0.16845
#
# Epoch 00262: val_loss improved from 0.16845 to 0.16782, saving model to ./model/262-0.1678.hdf5
#
# Epoch 00263: val_loss improved from 0.16782 to 0.16613, saving model to ./model/263-0.1661.hdf5
#
# Epoch 00264: val_loss improved from 0.16613 to 0.16579, saving model to ./model/264-0.1658.hdf5
#
# Epoch 00265: val_loss did not improve from 0.16579
#
# Epoch 00266: val_loss did not improve from 0.16579
#
# Epoch 00267: val_loss improved from 0.16579 to 0.16557, saving model to ./model/267-0.1656.hdf5
#
# Epoch 00268: val_loss improved from 0.16557 to 0.16447, saving model to ./model/268-0.1645.hdf5
#
# Epoch 00269: val_loss improved from 0.16447 to 0.16436, saving model to ./model/269-0.1644.hdf5
#
# Epoch 00270: val_loss did not improve from 0.16436
#
# Epoch 00271: val_loss did not improve from 0.16436
#
# Epoch 00272: val_loss did not improve from 0.16436
#
# Epoch 00273: val_loss improved from 0.16436 to 0.16396, saving model to ./model/273-0.1640.hdf5
#
# Epoch 00274: val_loss improved from 0.16396 to 0.16318, saving model to ./model/274-0.1632.hdf5
#
# Epoch 00275: val_loss did not improve from 0.16318
#
# Epoch 00276: val_loss improved from 0.16318 to 0.16278, saving model to ./model/276-0.1628.hdf5
#
# Epoch 00277: val_loss improved from 0.16278 to 0.16206, saving model to ./model/277-0.1621.hdf5
#
# Epoch 00278: val_loss improved from 0.16206 to 0.16169, saving model to ./model/278-0.1617.hdf5
#
# Epoch 00279: val_loss improved from 0.16169 to 0.16107, saving model to ./model/279-0.1611.hdf5
#
# Epoch 00280: val_loss improved from 0.16107 to 0.16074, saving model to ./model/280-0.1607.hdf5
#
# Epoch 00281: val_loss improved from 0.16074 to 0.16072, saving model to ./model/281-0.1607.hdf5
#
# Epoch 00282: val_loss did not improve from 0.16072
#
# Epoch 00283: val_loss did not improve from 0.16072
#
# Epoch 00284: val_loss did not improve from 0.16072
#
# Epoch 00285: val_loss improved from 0.16072 to 0.16034, saving model to ./model/285-0.1603.hdf5
#
# Epoch 00286: val_loss improved from 0.16034 to 0.15887, saving model to ./model/286-0.1589.hdf5
#
# Epoch 00287: val_loss improved from 0.15887 to 0.15717, saving model to ./model/287-0.1572.hdf5
#
# Epoch 00288: val_loss improved from 0.15717 to 0.15695, saving model to ./model/288-0.1570.hdf5
#
# Epoch 00289: val_loss did not improve from 0.15695
#
# Epoch 00290: val_loss did not improve from 0.15695
#
# Epoch 00291: val_loss did not improve from 0.15695
#
# Epoch 00292: val_loss did not improve from 0.15695
#
# Epoch 00293: val_loss improved from 0.15695 to 0.15578, saving model to ./model/293-0.1558.hdf5
#
# Epoch 00294: val_loss improved from 0.15578 to 0.15509, saving model to ./model/294-0.1551.hdf5
#
# Epoch 00295: val_loss improved from 0.15509 to 0.15445, saving model to ./model/295-0.1545.hdf5
#
# Epoch 00296: val_loss did not improve from 0.15445
#
# Epoch 00297: val_loss did not improve from 0.15445
#
# Epoch 00298: val_loss did not improve from 0.15445
#
# Epoch 00299: val_loss did not improve from 0.15445
#
# Epoch 00300: val_loss improved from 0.15445 to 0.15294, saving model to ./model/300-0.1529.hdf5
#
# Epoch 00301: val_loss improved from 0.15294 to 0.15114, saving model to ./model/301-0.1511.hdf5
#
# Epoch 00302: val_loss improved from 0.15114 to 0.15096, saving model to ./model/302-0.1510.hdf5
#
# Epoch 00303: val_loss did not improve from 0.15096
#
# Epoch 00304: val_loss did not improve from 0.15096
#
# Epoch 00305: val_loss did not improve from 0.15096
#
# Epoch 00306: val_loss did not improve from 0.15096
#
# Epoch 00307: val_loss did not improve from 0.15096
#
# Epoch 00308: val_loss improved from 0.15096 to 0.15018, saving model to ./model/308-0.1502.hdf5
#
# Epoch 00309: val_loss improved from 0.15018 to 0.14984, saving model to ./model/309-0.1498.hdf5
#
# Epoch 00310: val_loss did not improve from 0.14984
#
# Epoch 00311: val_loss did not improve from 0.14984
#
# Epoch 00312: val_loss improved from 0.14984 to 0.14883, saving model to ./model/312-0.1488.hdf5
#
# Epoch 00313: val_loss improved from 0.14883 to 0.14825, saving model to ./model/313-0.1482.hdf5
#
# Epoch 00314: val_loss improved from 0.14825 to 0.14814, saving model to ./model/314-0.1481.hdf5
#
# Epoch 00315: val_loss did not improve from 0.14814
#
# Epoch 00316: val_loss improved from 0.14814 to 0.14767, saving model to ./model/316-0.1477.hdf5
#
# Epoch 00317: val_loss did not improve from 0.14767
#
# Epoch 00318: val_loss did not improve from 0.14767
#
# Epoch 00319: val_loss did not improve from 0.14767
#
# Epoch 00320: val_loss improved from 0.14767 to 0.14569, saving model to ./model/320-0.1457.hdf5
#
# Epoch 00321: val_loss improved from 0.14569 to 0.14461, saving model to ./model/321-0.1446.hdf5
#
# Epoch 00322: val_loss improved from 0.14461 to 0.14422, saving model to ./model/322-0.1442.hdf5
#
# Epoch 00323: val_loss improved from 0.14422 to 0.14375, saving model to ./model/323-0.1438.hdf5
#
# Epoch 00324: val_loss improved from 0.14375 to 0.14339, saving model to ./model/324-0.1434.hdf5
#
# Epoch 00325: val_loss did not improve from 0.14339
#
# Epoch 00326: val_loss did not improve from 0.14339
#
# Epoch 00327: val_loss did not improve from 0.14339
#
# Epoch 00328: val_loss improved from 0.14339 to 0.14321, saving model to ./model/328-0.1432.hdf5
#
# Epoch 00329: val_loss improved from 0.14321 to 0.14265, saving model to ./model/329-0.1427.hdf5
#
# Epoch 00330: val_loss improved from 0.14265 to 0.14173, saving model to ./model/330-0.1417.hdf5
# Epoch 00331: val_loss improved from 0.14173 to 0.14164, saving model to ./model/331-0.1416.hdf5
#
# Epoch 00332: val_loss did not improve from 0.14164
#
# Epoch 00333: val_loss did not improve from 0.14164
#
# Epoch 00334: val_loss did not improve from 0.14164
#
# Epoch 00335: val_loss improved from 0.14164 to 0.14152, saving model to ./model/335-0.1415.hdf5
#
# Epoch 00336: val_loss improved from 0.14152 to 0.14076, saving model to ./model/336-0.1408.hdf5
#
# Epoch 00337: val_loss improved from 0.14076 to 0.13900, saving model to ./model/337-0.1390.hdf5
#
# Epoch 00338: val_loss did not improve from 0.13900
#
# Epoch 00339: val_loss did not improve from 0.13900
#
# Epoch 00340: val_loss did not improve from 0.13900
#
# Epoch 00341: val_loss did not improve from 0.13900
#
# Epoch 00342: val_loss did not improve from 0.13900
#
# Epoch 00343: val_loss did not improve from 0.13900
#
# Epoch 00344: val_loss did not improve from 0.13900
#
# Epoch 00345: val_loss improved from 0.13900 to 0.13796, saving model to ./model/345-0.1380.hdf5
#
# Epoch 00346: val_loss did not improve from 0.13796
#
# Epoch 00347: val_loss improved from 0.13796 to 0.13673, saving model to ./model/347-0.1367.hdf5
#
# Epoch 00348: val_loss improved from 0.13673 to 0.13645, saving model to ./model/348-0.1365.hdf5
#
# Epoch 00349: val_loss improved from 0.13645 to 0.13630, saving model to ./model/349-0.1363.hdf5
#
# Epoch 00350: val_loss improved from 0.13630 to 0.13594, saving model to ./model/350-0.1359.hdf5
#
# Epoch 00351: val_loss improved from 0.13594 to 0.13574, saving model to ./model/351-0.1357.hdf5
#
# Epoch 00352: val_loss did not improve from 0.13574
#
# Epoch 00353: val_loss did not improve from 0.13574
#
# Epoch 00354: val_loss did not improve from 0.13574
#
# Epoch 00355: val_loss improved from 0.13574 to 0.13407, saving model to ./model/355-0.1341.hdf5
#
# Epoch 00356: val_loss improved from 0.13407 to 0.13164, saving model to ./model/356-0.1316.hdf5
#
# Epoch 00357: val_loss improved from 0.13164 to 0.13157, saving model to ./model/357-0.1316.hdf5
#
# Epoch 00358: val_loss did not improve from 0.13157
#
# Epoch 00359: val_loss did not improve from 0.13157
#
# Epoch 00360: val_loss did not improve from 0.13157
#
# Epoch 00361: val_loss did not improve from 0.13157
#
# Epoch 00362: val_loss improved from 0.13157 to 0.12970, saving model to ./model/362-0.1297.hdf5
#
# Epoch 00363: val_loss improved from 0.12970 to 0.12898, saving model to ./model/363-0.1290.hdf5
#
# Epoch 00364: val_loss did not improve from 0.12898
#
# Epoch 00365: val_loss did not improve from 0.12898
#
# Epoch 00366: val_loss did not improve from 0.12898
#
# Epoch 00367: val_loss did not improve from 0.12898
#
# Epoch 00368: val_loss did not improve from 0.12898
#
# Epoch 00369: val_loss improved from 0.12898 to 0.12788, saving model to ./model/369-0.1279.hdf5
#
# Epoch 00370: val_loss did not improve from 0.12788
#
# Epoch 00371: val_loss did not improve from 0.12788
#
# Epoch 00372: val_loss did not improve from 0.12788
#
# Epoch 00373: val_loss did not improve from 0.12788
#
# Epoch 00374: val_loss did not improve from 0.12788
#
# Epoch 00375: val_loss improved from 0.12788 to 0.12786, saving model to ./model/375-0.1279.hdf5
#
# Epoch 00376: val_loss did not improve from 0.12786
#
# Epoch 00377: val_loss did not improve from 0.12786
#
# Epoch 00378: val_loss did not improve from 0.12786
#
# Epoch 00379: val_loss improved from 0.12786 to 0.12616, saving model to ./model/379-0.1262.hdf5
#
# Epoch 00380: val_loss improved from 0.12616 to 0.12585, saving model to ./model/380-0.1259.hdf5
#
# Epoch 00381: val_loss did not improve from 0.12585
#
# Epoch 00382: val_loss did not improve from 0.12585
#
# Epoch 00383: val_loss did not improve from 0.12585
#
# Epoch 00384: val_loss improved from 0.12585 to 0.12568, saving model to ./model/384-0.1257.hdf5
#
# Epoch 00385: val_loss improved from 0.12568 to 0.12502, saving model to ./model/385-0.1250.hdf5
#
# Epoch 00386: val_loss improved from 0.12502 to 0.12452, saving model to ./model/386-0.1245.hdf5
#
# Epoch 00387: val_loss improved from 0.12452 to 0.12439, saving model to ./model/387-0.1244.hdf5
#
# Epoch 00388: val_loss did not improve from 0.12439
#
# Epoch 00389: val_loss did not improve from 0.12439
#
# Epoch 00390: val_loss did not improve from 0.12439
#
# Epoch 00391: val_loss improved from 0.12439 to 0.12330, saving model to ./model/391-0.1233.hdf5
#
# Epoch 00392: val_loss improved from 0.12330 to 0.12136, saving model to ./model/392-0.1214.hdf5
#
# Epoch 00393: val_loss did not improve from 0.12136
#
# Epoch 00394: val_loss did not improve from 0.12136
#
# Epoch 00395: val_loss did not improve from 0.12136
#
# Epoch 00396: val_loss did not improve from 0.12136
#
# Epoch 00397: val_loss improved from 0.12136 to 0.12046, saving model to ./model/397-0.1205.hdf5
#
# Epoch 00398: val_loss did not improve from 0.12046
#
# Epoch 00399: val_loss did not improve from 0.12046
#
# Epoch 00400: val_loss did not improve from 0.12046
#
# Epoch 00401: val_loss did not improve from 0.12046
#
# Epoch 00402: val_loss did not improve from 0.12046
#
# Epoch 00403: val_loss improved from 0.12046 to 0.11844, saving model to ./model/403-0.1184.hdf5
#
# Epoch 00404: val_loss improved from 0.11844 to 0.11664, saving model to ./model/404-0.1166.hdf5
#
# Epoch 00405: val_loss did not improve from 0.11664
#
# Epoch 00406: val_loss did not improve from 0.11664
#
# Epoch 00407: val_loss did not improve from 0.11664
#
# Epoch 00408: val_loss did not improve from 0.11664
#
# Epoch 00409: val_loss did not improve from 0.11664
#
# Epoch 00410: val_loss improved from 0.11664 to 0.11646, saving model to ./model/410-0.1165.hdf5
#
# Epoch 00411: val_loss did not improve from 0.11646
#
# Epoch 00412: val_loss did not improve from 0.11646
#
# Epoch 00413: val_loss improved from 0.11646 to 0.11625, saving model to ./model/413-0.1162.hdf5
#
# Epoch 00414: val_loss did not improve from 0.11625
#
# Epoch 00415: val_loss improved from 0.11625 to 0.11486, saving model to ./model/415-0.1149.hdf5
#
# Epoch 00416: val_loss did not improve from 0.11486
#
# Epoch 00417: val_loss did not improve from 0.11486
#
# Epoch 00418: val_loss improved from 0.11486 to 0.11431, saving model to ./model/418-0.1143.hdf5
#
# Epoch 00419: val_loss did not improve from 0.11431
#
# Epoch 00420: val_loss improved from 0.11431 to 0.11380, saving model to ./model/420-0.1138.hdf5
#
# Epoch 00421: val_loss improved from 0.11380 to 0.11153, saving model to ./model/421-0.1115.hdf5
#
# Epoch 00422: val_loss improved from 0.11153 to 0.10992, saving model to ./model/422-0.1099.hdf5
#
# Epoch 00423: val_loss did not improve from 0.10992
#
# Epoch 00424: val_loss did not improve from 0.10992
#
# Epoch 00425: val_loss did not improve from 0.10992
#
# Epoch 00426: val_loss did not improve from 0.10992
#
# Epoch 00427: val_loss did not improve from 0.10992
#
# Epoch 00428: val_loss did not improve from 0.10992
#
# Epoch 00429: val_loss improved from 0.10992 to 0.10941, saving model to ./model/429-0.1094.hdf5
#
# Epoch 00430: val_loss improved from 0.10941 to 0.10728, saving model to ./model/430-0.1073.hdf5
#
# Epoch 00431: val_loss did not improve from 0.10728
#
# Epoch 00432: val_loss did not improve from 0.10728
#
# Epoch 00433: val_loss did not improve from 0.10728
#
# Epoch 00434: val_loss did not improve from 0.10728
#
# Epoch 00435: val_loss improved from 0.10728 to 0.10692, saving model to ./model/435-0.1069.hdf5
#
# Epoch 00436: val_loss did not improve from 0.10692
#
# Epoch 00437: val_loss improved from 0.10692 to 0.10663, saving model to ./model/437-0.1066.hdf5
#
# Epoch 00438: val_loss improved from 0.10663 to 0.10526, saving model to ./model/438-0.1053.hdf5
#
# Epoch 00439: val_loss improved from 0.10526 to 0.10462, saving model to ./model/439-0.1046.hdf5
#
# Epoch 00440: val_loss did not improve from 0.10462
#
# Epoch 00441: val_loss did not improve from 0.10462
#
# Epoch 00442: val_loss did not improve from 0.10462
#
# Epoch 00443: val_loss did not improve from 0.10462
#
# Epoch 00444: val_loss improved from 0.10462 to 0.10348, saving model to ./model/444-0.1035.hdf5
#
# Epoch 00445: val_loss improved from 0.10348 to 0.10280, saving model to ./model/445-0.1028.hdf5
#
# Epoch 00446: val_loss did not improve from 0.10280
#
# Epoch 00447: val_loss did not improve from 0.10280
#
# Epoch 00448: val_loss improved from 0.10280 to 0.10241, saving model to ./model/448-0.1024.hdf5
# Epoch 00449: val_loss improved from 0.10241 to 0.09976, saving model to ./model/449-0.0998.hdf5
#
# Epoch 00450: val_loss did not improve from 0.09976
#
# Epoch 00451: val_loss did not improve from 0.09976
#
# Epoch 00452: val_loss did not improve from 0.09976
#
# Epoch 00453: val_loss did not improve from 0.09976
#
# Epoch 00454: val_loss did not improve from 0.09976
#
# Epoch 00455: val_loss did not improve from 0.09976
#
# Epoch 00456: val_loss did not improve from 0.09976
#
# Epoch 00457: val_loss did not improve from 0.09976
#
# Epoch 00458: val_loss improved from 0.09976 to 0.09839, saving model to ./model/458-0.0984.hdf5
#
# Epoch 00459: val_loss improved from 0.09839 to 0.09740, saving model to ./model/459-0.0974.hdf5
#
# Epoch 00460: val_loss improved from 0.09740 to 0.09719, saving model to ./model/460-0.0972.hdf5
#
# Epoch 00461: val_loss did not improve from 0.09719
#
# Epoch 00462: val_loss did not improve from 0.09719
#
# Epoch 00463: val_loss did not improve from 0.09719
#
# Epoch 00464: val_loss did not improve from 0.09719
#
# Epoch 00465: val_loss improved from 0.09719 to 0.09599, saving model to ./model/465-0.0960.hdf5
#
# Epoch 00466: val_loss improved from 0.09599 to 0.09521, saving model to ./model/466-0.0952.hdf5
#
# Epoch 00467: val_loss did not improve from 0.09521
#
# Epoch 00468: val_loss did not improve from 0.09521
#
# Epoch 00469: val_loss did not improve from 0.09521
#
# Epoch 00470: val_loss did not improve from 0.09521
#
# Epoch 00471: val_loss did not improve from 0.09521
#
# Epoch 00472: val_loss did not improve from 0.09521
#
# Epoch 00473: val_loss did not improve from 0.09521
#
# Epoch 00474: val_loss improved from 0.09521 to 0.09480, saving model to ./model/474-0.0948.hdf5
#
# Epoch 00475: val_loss improved from 0.09480 to 0.09333, saving model to ./model/475-0.0933.hdf5
#
# Epoch 00476: val_loss did not improve from 0.09333
#
# Epoch 00477: val_loss did not improve from 0.09333
#
# Epoch 00478: val_loss did not improve from 0.09333
#
# Epoch 00479: val_loss did not improve from 0.09333
#
# Epoch 00480: val_loss did not improve from 0.09333
#
# Epoch 00481: val_loss improved from 0.09333 to 0.09193, saving model to ./model/481-0.0919.hdf5
#
# Epoch 00482: val_loss did not improve from 0.09193
#
# Epoch 00483: val_loss did not improve from 0.09193
#
# Epoch 00484: val_loss did not improve from 0.09193
#
# Epoch 00485: val_loss did not improve from 0.09193
#
# Epoch 00486: val_loss improved from 0.09193 to 0.09005, saving model to ./model/486-0.0900.hdf5
#
# Epoch 00487: val_loss did not improve from 0.09005
#
# Epoch 00488: val_loss did not improve from 0.09005
#
# Epoch 00489: val_loss improved from 0.09005 to 0.08977, saving model to ./model/489-0.0898.hdf5
#
# Epoch 00490: val_loss did not improve from 0.08977
#
# Epoch 00491: val_loss did not improve from 0.08977
#
# Epoch 00492: val_loss did not improve from 0.08977
#
# Epoch 00493: val_loss improved from 0.08977 to 0.08945, saving model to ./model/493-0.0895.hdf5
#
# Epoch 00494: val_loss improved from 0.08945 to 0.08783, saving model to ./model/494-0.0878.hdf5
#
# Epoch 00495: val_loss improved from 0.08783 to 0.08704, saving model to ./model/495-0.0870.hdf5
#
# Epoch 00496: val_loss did not improve from 0.08704
#
# Epoch 00497: val_loss did not improve from 0.08704
#
# Epoch 00498: val_loss did not improve from 0.08704
#
# Epoch 00499: val_loss improved from 0.08704 to 0.08603, saving model to ./model/499-0.0860.hdf5
#
# Epoch 00500: val_loss did not improve from 0.08603
#
# Epoch 00501: val_loss did not improve from 0.08603
#
# Epoch 00502: val_loss did not improve from 0.08603
#
# Epoch 00503: val_loss improved from 0.08603 to 0.08370, saving model to ./model/503-0.0837.hdf5
#
# Epoch 00504: val_loss did not improve from 0.08370
#
# Epoch 00505: val_loss did not improve from 0.08370
#
# Epoch 00506: val_loss did not improve from 0.08370
#
# Epoch 00507: val_loss did not improve from 0.08370
#
# Epoch 00508: val_loss improved from 0.08370 to 0.08241, saving model to ./model/508-0.0824.hdf5
#
# Epoch 00509: val_loss did not improve from 0.08241
#
# Epoch 00510: val_loss did not improve from 0.08241
#
# Epoch 00511: val_loss did not improve from 0.08241
#
# Epoch 00512: val_loss did not improve from 0.08241
#
# Epoch 00513: val_loss did not improve from 0.08241
#
# Epoch 00514: val_loss did not improve from 0.08241
#
# Epoch 00515: val_loss did not improve from 0.08241
#
# Epoch 00516: val_loss improved from 0.08241 to 0.08184, saving model to ./model/516-0.0818.hdf5
#
# Epoch 00517: val_loss improved from 0.08184 to 0.08175, saving model to ./model/517-0.0817.hdf5
#
# Epoch 00518: val_loss did not improve from 0.08175
#
# Epoch 00519: val_loss did not improve from 0.08175
#
# Epoch 00520: val_loss did not improve from 0.08175
#
# Epoch 00521: val_loss improved from 0.08175 to 0.08138, saving model to ./model/521-0.0814.hdf5
#
# Epoch 00522: val_loss improved from 0.08138 to 0.08130, saving model to ./model/522-0.0813.hdf5
#
# Epoch 00523: val_loss improved from 0.08130 to 0.07971, saving model to ./model/523-0.0797.hdf5
#
# Epoch 00524: val_loss did not improve from 0.07971
#
# Epoch 00525: val_loss did not improve from 0.07971
#
# Epoch 00526: val_loss did not improve from 0.07971
#
# Epoch 00527: val_loss improved from 0.07971 to 0.07898, saving model to ./model/527-0.0790.hdf5
#
# Epoch 00528: val_loss did not improve from 0.07898
#
# Epoch 00529: val_loss did not improve from 0.07898
#
# Epoch 00530: val_loss did not improve from 0.07898
#
# Epoch 00531: val_loss improved from 0.07898 to 0.07843, saving model to ./model/531-0.0784.hdf5
#
# Epoch 00532: val_loss improved from 0.07843 to 0.07667, saving model to ./model/532-0.0767.hdf5
#
# Epoch 00533: val_loss did not improve from 0.07667
#
# Epoch 00534: val_loss did not improve from 0.07667
#
# Epoch 00535: val_loss did not improve from 0.07667
#
# Epoch 00536: val_loss improved from 0.07667 to 0.07662, saving model to ./model/536-0.0766.hdf5
#
# Epoch 00537: val_loss improved from 0.07662 to 0.07589, saving model to ./model/537-0.0759.hdf5
#
# Epoch 00538: val_loss did not improve from 0.07589
#
# Epoch 00539: val_loss did not improve from 0.07589
#
# Epoch 00540: val_loss did not improve from 0.07589
#
# Epoch 00541: val_loss improved from 0.07589 to 0.07541, saving model to ./model/541-0.0754.hdf5
#
# Epoch 00542: val_loss did not improve from 0.07541
#
# Epoch 00543: val_loss did not improve from 0.07541
#
# Epoch 00544: val_loss did not improve from 0.07541
#
# Epoch 00545: val_loss did not improve from 0.07541
#
# Epoch 00546: val_loss did not improve from 0.07541
#
# Epoch 00547: val_loss did not improve from 0.07541
#
# Epoch 00548: val_loss did not improve from 0.07541
#
# Epoch 00549: val_loss did not improve from 0.07541
#
# Epoch 00550: val_loss improved from 0.07541 to 0.07441, saving model to ./model/550-0.0744.hdf5
#
# Epoch 00551: val_loss did not improve from 0.07441
#
# Epoch 00552: val_loss did not improve from 0.07441
#
# Epoch 00553: val_loss did not improve from 0.07441
#
# Epoch 00554: val_loss improved from 0.07441 to 0.07291, saving model to ./model/554-0.0729.hdf5
#
# Epoch 00555: val_loss did not improve from 0.07291
#
# Epoch 00556: val_loss did not improve from 0.07291
#
# Epoch 00557: val_loss did not improve from 0.07291
#
# Epoch 00558: val_loss did not improve from 0.07291
#
# Epoch 00559: val_loss did not improve from 0.07291
#
# Epoch 00560: val_loss improved from 0.07291 to 0.07215, saving model to ./model/560-0.0722.hdf5
#
# Epoch 00561: val_loss did not improve from 0.07215
#
# Epoch 00562: val_loss improved from 0.07215 to 0.07197, saving model to ./model/562-0.0720.hdf5
#
# Epoch 00563: val_loss improved from 0.07197 to 0.07182, saving model to ./model/563-0.0718.hdf5
#
# Epoch 00564: val_loss improved from 0.07182 to 0.07171, saving model to ./model/564-0.0717.hdf5
#
# Epoch 00565: val_loss improved from 0.07171 to 0.07149, saving model to ./model/565-0.0715.hdf5
#
# Epoch 00566: val_loss did not improve from 0.07149
#
# Epoch 00567: val_loss did not improve from 0.07149
#
# Epoch 00568: val_loss did not improve from 0.07149
#
# Epoch 00569: val_loss improved from 0.07149 to 0.07122, saving model to ./model/569-0.0712.hdf5
#
# Epoch 00570: val_loss did not improve from 0.07122
#
# Epoch 00571: val_loss did not improve from 0.07122
#
# Epoch 00572: val_loss did not improve from 0.07122
#
# Epoch 00573: val_loss did not improve from 0.07122
#
# Epoch 00574: val_loss improved from 0.07122 to 0.06907, saving model to ./model/574-0.0691.hdf5
#
# Epoch 00575: val_loss improved from 0.06907 to 0.06887, saving model to ./model/575-0.0689.hdf5
#
# Epoch 00576: val_loss did not improve from 0.06887
#
# Epoch 00577: val_loss did not improve from 0.06887
#
# Epoch 00578: val_loss did not improve from 0.06887
#
# Epoch 00579: val_loss improved from 0.06887 to 0.06886, saving model to ./model/579-0.0689.hdf5
#
# Epoch 00580: val_loss improved from 0.06886 to 0.06795, saving model to ./model/580-0.0680.hdf5
# Epoch 00581: val_loss did not improve from 0.06795
#
# Epoch 00582: val_loss did not improve from 0.06795
#
# Epoch 00583: val_loss did not improve from 0.06795
#
# Epoch 00584: val_loss did not improve from 0.06795
#
# Epoch 00585: val_loss did not improve from 0.06795
#
# Epoch 00586: val_loss improved from 0.06795 to 0.06788, saving model to ./model/586-0.0679.hdf5
#
# Epoch 00587: val_loss did not improve from 0.06788
#
# Epoch 00588: val_loss improved from 0.06788 to 0.06750, saving model to ./model/588-0.0675.hdf5
#
# Epoch 00589: val_loss did not improve from 0.06750
#
# Epoch 00590: val_loss improved from 0.06750 to 0.06683, saving model to ./model/590-0.0668.hdf5
#
# Epoch 00591: val_loss did not improve from 0.06683
#
# Epoch 00592: val_loss did not improve from 0.06683
#
# Epoch 00593: val_loss improved from 0.06683 to 0.06570, saving model to ./model/593-0.0657.hdf5
#
# Epoch 00594: val_loss improved from 0.06570 to 0.06473, saving model to ./model/594-0.0647.hdf5
#
# Epoch 00595: val_loss did not improve from 0.06473
#
# Epoch 00596: val_loss did not improve from 0.06473
#
# Epoch 00597: val_loss did not improve from 0.06473
#
# Epoch 00598: val_loss improved from 0.06473 to 0.06334, saving model to ./model/598-0.0633.hdf5
#
# Epoch 00599: val_loss did not improve from 0.06334
#
# Epoch 00600: val_loss did not improve from 0.06334
#
# Epoch 00601: val_loss did not improve from 0.06334
#
# Epoch 00602: val_loss did not improve from 0.06334
#
# Epoch 00603: val_loss did not improve from 0.06334
#
# Epoch 00604: val_loss improved from 0.06334 to 0.06292, saving model to ./model/604-0.0629.hdf5
#
# Epoch 00605: val_loss improved from 0.06292 to 0.06231, saving model to ./model/605-0.0623.hdf5
#
# Epoch 00606: val_loss did not improve from 0.06231
#
# Epoch 00607: val_loss did not improve from 0.06231
#
# Epoch 00608: val_loss improved from 0.06231 to 0.06191, saving model to ./model/608-0.0619.hdf5
#
# Epoch 00609: val_loss did not improve from 0.06191
#
# Epoch 00610: val_loss did not improve from 0.06191
#
# Epoch 00611: val_loss did not improve from 0.06191
#
# Epoch 00612: val_loss did not improve from 0.06191
#
# Epoch 00613: val_loss did not improve from 0.06191
#
# Epoch 00614: val_loss did not improve from 0.06191
#
# Epoch 00615: val_loss did not improve from 0.06191
#
# Epoch 00616: val_loss did not improve from 0.06191
#
# Epoch 00617: val_loss did not improve from 0.06191
#
# Epoch 00618: val_loss improved from 0.06191 to 0.06100, saving model to ./model/618-0.0610.hdf5
#
# Epoch 00619: val_loss improved from 0.06100 to 0.06043, saving model to ./model/619-0.0604.hdf5
#
# Epoch 00620: val_loss did not improve from 0.06043
#
# Epoch 00621: val_loss did not improve from 0.06043
#
# Epoch 00622: val_loss did not improve from 0.06043
#
# Epoch 00623: val_loss did not improve from 0.06043
#
# Epoch 00624: val_loss did not improve from 0.06043
#
# Epoch 00625: val_loss improved from 0.06043 to 0.05946, saving model to ./model/625-0.0595.hdf5
#
# Epoch 00626: val_loss did not improve from 0.05946
#
# Epoch 00627: val_loss did not improve from 0.05946
#
# Epoch 00628: val_loss did not improve from 0.05946
#
# Epoch 00629: val_loss improved from 0.05946 to 0.05872, saving model to ./model/629-0.0587.hdf5
#
# Epoch 00630: val_loss did not improve from 0.05872
#
# Epoch 00631: val_loss did not improve from 0.05872
#
# Epoch 00632: val_loss did not improve from 0.05872
#
# Epoch 00633: val_loss improved from 0.05872 to 0.05819, saving model to ./model/633-0.0582.hdf5
#
# Epoch 00634: val_loss did not improve from 0.05819
#
# Epoch 00635: val_loss did not improve from 0.05819
#
# Epoch 00636: val_loss did not improve from 0.05819
#
# Epoch 00637: val_loss did not improve from 0.05819
#
# Epoch 00638: val_loss improved from 0.05819 to 0.05758, saving model to ./model/638-0.0576.hdf5
#
# Epoch 00639: val_loss did not improve from 0.05758
#
# Epoch 00640: val_loss did not improve from 0.05758
#
# Epoch 00641: val_loss did not improve from 0.05758
#
# Epoch 00642: val_loss improved from 0.05758 to 0.05672, saving model to ./model/642-0.0567.hdf5
#
# Epoch 00643: val_loss did not improve from 0.05672
#
# Epoch 00644: val_loss did not improve from 0.05672
#
# Epoch 00645: val_loss did not improve from 0.05672
#
# Epoch 00646: val_loss did not improve from 0.05672
#
# Epoch 00647: val_loss improved from 0.05672 to 0.05661, saving model to ./model/647-0.0566.hdf5
#
# Epoch 00648: val_loss did not improve from 0.05661
#
# Epoch 00649: val_loss did not improve from 0.05661
#
# Epoch 00650: val_loss did not improve from 0.05661
#
# Epoch 00651: val_loss did not improve from 0.05661
#
# Epoch 00652: val_loss did not improve from 0.05661
#
# Epoch 00653: val_loss did not improve from 0.05661
#
# Epoch 00654: val_loss did not improve from 0.05661
#
# Epoch 00655: val_loss did not improve from 0.05661
#
# Epoch 00656: val_loss improved from 0.05661 to 0.05639, saving model to ./model/656-0.0564.hdf5
#
# ...
#
# Epoch 01153: val_loss did not improve from 0.02915
#
# Epoch 01154: val_loss did not improve from 0.02915
#
# Epoch 01155: val_loss did not improve from 0.02915
#
# Epoch 01156: val_loss did not improve from 0.02915
#
# Epoch 01157: val_loss did not improve from 0.02915
#
# Epoch 01158: val_loss did not improve from 0.02915
#
# Epoch 01159: val_loss did not improve from 0.02915
#
# Epoch 01160: val_loss did not improve from 0.02915
#
# Epoch 01161: val_loss did not improve from 0.02915
#
# Epoch 01162: val_loss did not improve from 0.02915
#
# Epoch 01163: val_loss did not improve from 0.02915
#
# Epoch 01164: val_loss did not improve from 0.02915
#
# Epoch 01165: val_loss did not improve from 0.02915
#
# Epoch 01166: val_loss did not improve from 0.02915
#
# Epoch 01167: val_loss did not improve from 0.02915
#
# Epoch 01168: val_loss did not improve from 0.02915
#
# Epoch 01169: val_loss did not improve from 0.02915
#
# Epoch 01170: val_loss did not improve from 0.02915
# Epoch 01171: val_loss did not improve from 0.02915
#
# Epoch 01172: val_loss did not improve from 0.02915
#
# Epoch 01173: val_loss did not improve from 0.02915
#
# Epoch 01174: val_loss did not improve from 0.02915
#
# Epoch 01175: val_loss did not improve from 0.02915
#
# Epoch 01176: val_loss did not improve from 0.02915
#
# Epoch 01177: val_loss did not improve from 0.02915
#
# Epoch 01178: val_loss did not improve from 0.02915
#
# Epoch 01179: val_loss did not improve from 0.02915
#
# Epoch 01180: val_loss did not improve from 0.02915
#
# Epoch 01181: val_loss did not improve from 0.02915
#
# Epoch 01182: val_loss did not improve from 0.02915
#
# Epoch 01183: val_loss did not improve from 0.02915
#
# Epoch 01184: val_loss did not improve from 0.02915
#
# Epoch 01185: val_loss did not improve from 0.02915
#
# Epoch 01186: val_loss did not improve from 0.02915
#
# Epoch 01187: val_loss did not improve from 0.02915
#
# Epoch 01188: val_loss did not improve from 0.02915
#
# Epoch 01189: val_loss did not improve from 0.02915
#
# Epoch 01190: val_loss did not improve from 0.02915
#
# Epoch 01191: val_loss did not improve from 0.02915
#
# Epoch 01192: val_loss did not improve from 0.02915
#
# Epoch 01193: val_loss did not improve from 0.02915
#
# Epoch 01194: val_loss did not improve from 0.02915
#
# Epoch 01195: val_loss did not improve from 0.02915
#
# Epoch 01196: val_loss did not improve from 0.02915
#
# Epoch 01197: val_loss did not improve from 0.02915
#
# Epoch 01198: val_loss did not improve from 0.02915
#
# Epoch 01199: val_loss did not improve from 0.02915
#
# Epoch 01200: val_loss improved from 0.02915 to 0.02911, saving model to ./model/1200-0.0291.hdf5
#
# Epoch 01201: val_loss did not improve from 0.02911
#
# Epoch 01202: val_loss did not improve from 0.02911
#
# Epoch 01203: val_loss did not improve from 0.02911
#
# Epoch 01204: val_loss did not improve from 0.02911
#
# Epoch 01205: val_loss did not improve from 0.02911
#
# Epoch 01206: val_loss did not improve from 0.02911
#
# Epoch 01207: val_loss did not improve from 0.02911
#
# Epoch 01208: val_loss did not improve from 0.02911
#
# Epoch 01209: val_loss did not improve from 0.02911
#
# Epoch 01210: val_loss did not improve from 0.02911
#
# Epoch 01211: val_loss did not improve from 0.02911
#
# Epoch 01212: val_loss did not improve from 0.02911
#
# Epoch 01213: val_loss did not improve from 0.02911
#
# Epoch 01214: val_loss did not improve from 0.02911
#
# Epoch 01215: val_loss did not improve from 0.02911
#
# Epoch 01216: val_loss did not improve from 0.02911
#
# Epoch 01217: val_loss did not improve from 0.02911
#
# Epoch 01218: val_loss did not improve from 0.02911
#
# Epoch 01219: val_loss did not improve from 0.02911
#
# Epoch 01220: val_loss did not improve from 0.02911
#
# Epoch 01221: val_loss did not improve from 0.02911
#
# Epoch 01222: val_loss did not improve from 0.02911
#
# Epoch 01223: val_loss did not improve from 0.02911
#
# Epoch 01224: val_loss did not improve from 0.02911
#
# Epoch 01225: val_loss did not improve from 0.02911
#
# Epoch 01226: val_loss did not improve from 0.02911
#
# Epoch 01227: val_loss did not improve from 0.02911
#
# Epoch 01228: val_loss did not improve from 0.02911
#
# Epoch 01229: val_loss did not improve from 0.02911
#
# Epoch 01230: val_loss did not improve from 0.02911
#
# Epoch 01231: val_loss did not improve from 0.02911
#
# Epoch 01232: val_loss did not improve from 0.02911
#
# Epoch 01233: val_loss did not improve from 0.02911
#
# Epoch 01234: val_loss did not improve from 0.02911
#
# Epoch 01235: val_loss did not improve from 0.02911
#
# Epoch 01236: val_loss did not improve from 0.02911
#
# Epoch 01237: val_loss did not improve from 0.02911
#
# Epoch 01238: val_loss did not improve from 0.02911
#
# Epoch 01239: val_loss did not improve from 0.02911
#
# Epoch 01240: val_loss did not improve from 0.02911
#
# Epoch 01241: val_loss did not improve from 0.02911
#
# Epoch 01242: val_loss did not improve from 0.02911
#
# Epoch 01243: val_loss did not improve from 0.02911
#
# Epoch 01244: val_loss did not improve from 0.02911
#
# Epoch 01245: val_loss did not improve from 0.02911
#
# Epoch 01246: val_loss did not improve from 0.02911
#
# Epoch 01247: val_loss did not improve from 0.02911
#
# Epoch 01248: val_loss did not improve from 0.02911
#
# Epoch 01249: val_loss did not improve from 0.02911
#
# Epoch 01250: val_loss did not improve from 0.02911
#
# Epoch 01251: val_loss did not improve from 0.02911
#
# Epoch 01252: val_loss did not improve from 0.02911
#
# Epoch 01253: val_loss did not improve from 0.02911
#
# Epoch 01254: val_loss did not improve from 0.02911
#
# Epoch 01255: val_loss did not improve from 0.02911
#
# Epoch 01256: val_loss did not improve from 0.02911
#
# Epoch 01257: val_loss did not improve from 0.02911
#
# Epoch 01258: val_loss did not improve from 0.02911
#
# Epoch 01259: val_loss improved from 0.02911 to 0.02886, saving model to ./model/1259-0.0289.hdf5
#
# Epoch 01260: val_loss did not improve from 0.02886
#
# Epoch 01261: val_loss did not improve from 0.02886
#
# Epoch 01262: val_loss did not improve from 0.02886
#
# Epoch 01263: val_loss did not improve from 0.02886
#
# Epoch 01264: val_loss did not improve from 0.02886
#
# Epoch 01265: val_loss did not improve from 0.02886
#
# Epoch 01266: val_loss did not improve from 0.02886
#
# Epoch 01267: val_loss did not improve from 0.02886
#
# Epoch 01268: val_loss did not improve from 0.02886
#
# Epoch 01269: val_loss did not improve from 0.02886
#
# Epoch 01270: val_loss did not improve from 0.02886
#
# Epoch 01271: val_loss did not improve from 0.02886
#
# Epoch 01272: val_loss did not improve from 0.02886
#
# Epoch 01273: val_loss did not improve from 0.02886
#
# Epoch 01274: val_loss did not improve from 0.02886
#
# Epoch 01275: val_loss did not improve from 0.02886
#
# Epoch 01276: val_loss did not improve from 0.02886
#
# Epoch 01277: val_loss did not improve from 0.02886
#
# Epoch 01278: val_loss did not improve from 0.02886
#
# Epoch 01279: val_loss did not improve from 0.02886
#
# Epoch 01280: val_loss improved from 0.02886 to 0.02871, saving model to ./model/1280-0.0287.hdf5
#
# Epoch 01281: val_loss did not improve from 0.02871
#
# Epoch 01282: val_loss did not improve from 0.02871
#
# Epoch 01283: val_loss did not improve from 0.02871
#
# Epoch 01284: val_loss did not improve from 0.02871
#
# Epoch 01285: val_loss did not improve from 0.02871
#
# Epoch 01286: val_loss did not improve from 0.02871
#
# Epoch 01287: val_loss did not improve from 0.02871
#
# Epoch 01288: val_loss did not improve from 0.02871
#
# Epoch 01289: val_loss did not improve from 0.02871
#
# Epoch 01290: val_loss did not improve from 0.02871
#
# Epoch 01291: val_loss did not improve from 0.02871
#
# Epoch 01292: val_loss did not improve from 0.02871
#
# Epoch 01293: val_loss did not improve from 0.02871
#
# Epoch 01294: val_loss did not improve from 0.02871
#
# Epoch 01295: val_loss did not improve from 0.02871
#
# Epoch 01296: val_loss did not improve from 0.02871
#
# Epoch 01297: val_loss did not improve from 0.02871
#
# Epoch 01298: val_loss did not improve from 0.02871
#
# Epoch 01299: val_loss did not improve from 0.02871
#
# Epoch 01300: val_loss did not improve from 0.02871
#
# Epoch 01301: val_loss did not improve from 0.02871
#
# Epoch 01302: val_loss did not improve from 0.02871
#
# Epoch 01303: val_loss did not improve from 0.02871
#
# Epoch 01304: val_loss did not improve from 0.02871
#
# Epoch 01305: val_loss did not improve from 0.02871
#
# Epoch 01306: val_loss did not improve from 0.02871
#
# Epoch 01307: val_loss did not improve from 0.02871
#
# Epoch 01308: val_loss did not improve from 0.02871
#
# Epoch 01309: val_loss did not improve from 0.02871
#
# Epoch 01310: val_loss did not improve from 0.02871
#
# Epoch 01311: val_loss did not improve from 0.02871
#
# Epoch 01312: val_loss did not improve from 0.02871
#
# Epoch 01313: val_loss did not improve from 0.02871
#
# Epoch 01314: val_loss did not improve from 0.02871
#
# Epoch 01315: val_loss did not improve from 0.02871
#
# Epoch 01316: val_loss did not improve from 0.02871
#
# Epoch 01317: val_loss did not improve from 0.02871
#
# Epoch 01318: val_loss did not improve from 0.02871
#
# Epoch 01319: val_loss did not improve from 0.02871
#
# Epoch 01320: val_loss did not improve from 0.02871
#
# Epoch 01321: val_loss did not improve from 0.02871
#
# Epoch 01322: val_loss did not improve from 0.02871
#
# Epoch 01323: val_loss did not improve from 0.02871
#
# Epoch 01324: val_loss did not improve from 0.02871
#
# Epoch 01325: val_loss did not improve from 0.02871
#
# Epoch 01326: val_loss did not improve from 0.02871
#
# Epoch 01327: val_loss did not improve from 0.02871
#
# Epoch 01328: val_loss did not improve from 0.02871
#
# Epoch 01329: val_loss did not improve from 0.02871
#
# Epoch 01330: val_loss did not improve from 0.02871
#
# Epoch 01331: val_loss did not improve from 0.02871
#
# Epoch 01332: val_loss did not improve from 0.02871
#
# Epoch 01333: val_loss did not improve from 0.02871
#
# Epoch 01334: val_loss did not improve from 0.02871
#
# Epoch 01335: val_loss did not improve from 0.02871
#
# Epoch 01336: val_loss did not improve from 0.02871
#
# Epoch 01337: val_loss did not improve from 0.02871
#
# Epoch 01338: val_loss did not improve from 0.02871
#
# Epoch 01339: val_loss did not improve from 0.02871
#
# Epoch 01340: val_loss did not improve from 0.02871
#
# Epoch 01341: val_loss did not improve from 0.02871
#
# Epoch 01342: val_loss did not improve from 0.02871
#
# Epoch 01343: val_loss did not improve from 0.02871
# Epoch 01344: val_loss did not improve from 0.02871
#
# Epoch 01345: val_loss did not improve from 0.02871
#
# Epoch 01346: val_loss did not improve from 0.02871
#
# Epoch 01347: val_loss did not improve from 0.02871
#
# Epoch 01348: val_loss did not improve from 0.02871
#
# Epoch 01349: val_loss did not improve from 0.02871
#
# Epoch 01350: val_loss did not improve from 0.02871
#
# Epoch 01351: val_loss did not improve from 0.02871
#
# Epoch 01352: val_loss did not improve from 0.02871
#
# Epoch 01353: val_loss did not improve from 0.02871
#
# Epoch 01354: val_loss improved from 0.02871 to 0.02846, saving model to ./model/1354-0.0285.hdf5
#
# Epoch 01355: val_loss did not improve from 0.02846
#
# Epoch 01356: val_loss did not improve from 0.02846
#
# Epoch 01357: val_loss did not improve from 0.02846
#
# Epoch 01358: val_loss did not improve from 0.02846
#
# Epoch 01359: val_loss did not improve from 0.02846
#
# Epoch 01360: val_loss did not improve from 0.02846
#
# Epoch 01361: val_loss did not improve from 0.02846
#
# Epoch 01362: val_loss did not improve from 0.02846
#
# Epoch 01363: val_loss did not improve from 0.02846
#
# Epoch 01364: val_loss did not improve from 0.02846
#
# Epoch 01365: val_loss did not improve from 0.02846
#
# Epoch 01366: val_loss did not improve from 0.02846
#
# Epoch 01367: val_loss did not improve from 0.02846
#
# Epoch 01368: val_loss did not improve from 0.02846
#
# Epoch 01369: val_loss did not improve from 0.02846
#
# Epoch 01370: val_loss did not improve from 0.02846
#
# Epoch 01371: val_loss did not improve from 0.02846
#
# Epoch 01372: val_loss did not improve from 0.02846
#
# Epoch 01373: val_loss did not improve from 0.02846
#
# Epoch 01374: val_loss did not improve from 0.02846
#
# Epoch 01375: val_loss did not improve from 0.02846
#
# Epoch 01376: val_loss did not improve from 0.02846
#
# Epoch 01377: val_loss did not improve from 0.02846
#
# Epoch 01378: val_loss did not improve from 0.02846
#
# Epoch 01379: val_loss did not improve from 0.02846
#
# Epoch 01380: val_loss did not improve from 0.02846
#
# Epoch 01381: val_loss did not improve from 0.02846
#
# Epoch 01382: val_loss did not improve from 0.02846
#
# Epoch 01383: val_loss did not improve from 0.02846
#
# Epoch 01384: val_loss did not improve from 0.02846
#
# Epoch 01385: val_loss did not improve from 0.02846
#
# Epoch 01386: val_loss did not improve from 0.02846
#
# Epoch 01387: val_loss did not improve from 0.02846
#
# Epoch 01388: val_loss did not improve from 0.02846
#
# Epoch 01389: val_loss did not improve from 0.02846
#
# Epoch 01390: val_loss did not improve from 0.02846
#
# Epoch 01391: val_loss did not improve from 0.02846
#
# Epoch 01392: val_loss did not improve from 0.02846
#
# Epoch 01393: val_loss did not improve from 0.02846
#
# Epoch 01394: val_loss did not improve from 0.02846
#
# Epoch 01395: val_loss did not improve from 0.02846
#
# Epoch 01396: val_loss did not improve from 0.02846
#
# Epoch 01397: val_loss did not improve from 0.02846
#
# Epoch 01398: val_loss did not improve from 0.02846
#
# Epoch 01399: val_loss did not improve from 0.02846
#
# Epoch 01400: val_loss did not improve from 0.02846
#
# Epoch 01401: val_loss did not improve from 0.02846
#
# Epoch 01402: val_loss did not improve from 0.02846
#
# Epoch 01403: val_loss did not improve from 0.02846
#
# Epoch 01404: val_loss did not improve from 0.02846
#
# Epoch 01405: val_loss did not improve from 0.02846
#
# Epoch 01406: val_loss did not improve from 0.02846
#
# Epoch 01407: val_loss did not improve from 0.02846
#
# Epoch 01408: val_loss did not improve from 0.02846
#
# Epoch 01409: val_loss did not improve from 0.02846
#
# Epoch 01410: val_loss did not improve from 0.02846
#
# Epoch 01411: val_loss did not improve from 0.02846
#
# Epoch 01412: val_loss did not improve from 0.02846
#
# Epoch 01413: val_loss did not improve from 0.02846
#
# Epoch 01414: val_loss did not improve from 0.02846
#
# Epoch 01415: val_loss did not improve from 0.02846
#
# Epoch 01416: val_loss did not improve from 0.02846
#
# Epoch 01417: val_loss did not improve from 0.02846
#
# Epoch 01418: val_loss did not improve from 0.02846
#
# Epoch 01419: val_loss did not improve from 0.02846
#
# Epoch 01420: val_loss did not improve from 0.02846
#
# Epoch 01421: val_loss did not improve from 0.02846
#
# Epoch 01422: val_loss did not improve from 0.02846
#
# Epoch 01423: val_loss did not improve from 0.02846
#
# Epoch 01424: val_loss did not improve from 0.02846
#
# Epoch 01425: val_loss did not improve from 0.02846
#
# Epoch 01426: val_loss did not improve from 0.02846
#
# Epoch 01427: val_loss did not improve from 0.02846
#
# Epoch 01428: val_loss did not improve from 0.02846
#
# Epoch 01429: val_loss did not improve from 0.02846
#
# Epoch 01430: val_loss did not improve from 0.02846
#
# Epoch 01431: val_loss did not improve from 0.02846
#
# Epoch 01432: val_loss did not improve from 0.02846
#
# Epoch 01433: val_loss did not improve from 0.02846
#
# Epoch 01434: val_loss did not improve from 0.02846
#
# Epoch 01435: val_loss did not improve from 0.02846
#
# Epoch 01436: val_loss did not improve from 0.02846
#
# Epoch 01437: val_loss did not improve from 0.02846
#
# Epoch 01438: val_loss did not improve from 0.02846
#
# Epoch 01439: val_loss did not improve from 0.02846
#
# Epoch 01440: val_loss did not improve from 0.02846
#
# Epoch 01441: val_loss did not improve from 0.02846
#
# Epoch 01442: val_loss did not improve from 0.02846
#
# Epoch 01443: val_loss did not improve from 0.02846
#
# Epoch 01444: val_loss did not improve from 0.02846
#
# Epoch 01445: val_loss did not improve from 0.02846
#
# Epoch 01446: val_loss did not improve from 0.02846
#
# Epoch 01447: val_loss did not improve from 0.02846
#
# Epoch 01448: val_loss did not improve from 0.02846
#
# Epoch 01449: val_loss did not improve from 0.02846
#
# Epoch 01450: val_loss did not improve from 0.02846
#
# Epoch 01451: val_loss did not improve from 0.02846
#
# Epoch 01452: val_loss did not improve from 0.02846
#
# Epoch 01453: val_loss did not improve from 0.02846
#
# Epoch 01454: val_loss did not improve from 0.02846
# 975/975 [==============================] - 0s 18us/step
#
#  Accuracy : 0.9938
